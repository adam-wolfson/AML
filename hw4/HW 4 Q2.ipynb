# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import math

# %%
data = pd.read_csv("OJ.csv")

# %%
x = data.drop(columns = ['Purchase', 'Unnamed: 0'])
y = data['Purchase']
y.head()
# Out:
# 0    CH
# 1    CH
# 2    CH
# 3    MM
# 4    CH
# Name: Purchase, dtype: object

# %%
x["Store7"] = x["Store7"].astype('category')
x["Store7"] = x["Store7"].cat.codes
x.head()
# Out:
#    WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  SpecialCH  \
# 0             237        1     1.75     1.99    0.00     0.0          0
# 1             239        1     1.75     1.99    0.00     0.3          0
# 2             245        1     1.86     2.09    0.17     0.0          0
# 3             227        1     1.69     1.69    0.00     0.0          0
# 4             228        7     1.69     1.69    0.00     0.0          0
#
#    SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff  Store7  \
# 0          0  0.500000         1.99         1.75       0.24       0
# 1          1  0.600000         1.69         1.75      -0.06       0
# 2          0  0.680000         2.09         1.69       0.40       0
# 3          0  0.400000         1.69         1.69       0.00       0
# 4          0  0.956535         1.69         1.69       0.00       1
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 0   0.000000   0.000000           0.24      1
# 1   0.150754   0.000000           0.24      1
# 2   0.000000   0.091398           0.23      1
# 3   0.000000   0.000000           0.00      1
# 4   0.000000   0.000000           0.00      0

# %%
test_frac = (len(data)-800.0)/len(data)
test_frac
# Out:
# 0.2523364485981308

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=test_frac)

# %%
print(len(X_train),len(X_test))
# Out:
# 800 270

# %% [markdown]
# ##### a)

# %%
y_train.value_counts('CH')
# Out:
# CH    0.61
# MM    0.39
# Name: Purchase, dtype: float64

# %%
y_test.value_counts('CH')
# Out:
# CH    0.611111
# MM    0.388889
# Name: Purchase, dtype: float64

# %%
X_test.head()
# Out:
#      WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  SpecialCH  \
# 77              251        4     1.99     2.23     0.0    0.00          0
# 603             262        7     1.86     2.13     0.0    0.00          0
# 131             271        2     1.86     2.18     0.0    0.06          0
# 821             228        4     1.79     1.79     0.0    0.00          0
# 945             258        2     1.86     2.18     0.0    0.00          0
#
#      SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff  Store7  \
# 77           0  0.836160         2.23         1.99       0.24       0
# 603          0  0.977130         2.13         1.86       0.27       1
# 131          0  0.944076         2.12         1.86       0.26       0
# 821          0  0.740314         1.79         1.79       0.00       0
# 945          0  0.018201         2.18         1.86       0.32       0
#
#      PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 77    0.000000        0.0           0.24      4
# 603   0.000000        0.0           0.27      0
# 131   0.027523        0.0           0.32      2
# 821   0.000000        0.0           0.00      4
# 945   0.000000        0.0           0.32      2

# %%
linearSVM = svm.SVC(kernel= 'linear', C= 0.01)
linearSVM.fit(X_train, y_train)
# Out:
# SVC(C=0.01, kernel='linear')

# %% [markdown]
# ##### b)

# %%
linearSVM.get_params()
# Out:
# {'C': 0.01,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'linear',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
margin = 1 / np.sqrt(np.sum(linearSVM.coef_ ** 2))
margin
# Out:
# 0.8689800260289876

# %%
len(linearSVM.support_vectors_)
# Out:
# 622

# %%
linearSVM.support_vectors_[0]
# Out:
# array([2.72000e+02, 2.00000e+00, 1.86000e+00, 2.18000e+00, 0.00000e+00,
#        6.00000e-02, 0.00000e+00, 0.00000e+00, 4.71378e-01, 2.12000e+00,
#        1.86000e+00, 2.60000e-01, 0.00000e+00, 2.75230e-02, 0.00000e+00,
#        3.20000e-01, 2.00000e+00])

# %%
testPreds = linearSVM.predict(X_test)
trainPreds = linearSVM.predict(X_train)

# %% [markdown]
# This classifier has 622 support vectors and a margin of 0.87, and an error on the test set of 0.23. This tells us that only 622 data points from the training set provide meaningful information for our model to create the separating hyperplane. We also see that because there is error both on the training and testing set that this classifier cannot cleanly separate the data using linear hyperplanes.

# %% [markdown]
# ##### c)

# %%
print("Train error is:",1-accuracy_score(y_train, trainPreds), "   Test error is:",1-accuracy_score(y_test,testPreds))
# Out:
# Train error is: 0.20750000000000002    Test error is: 0.22962962962962963

# %%
def range_with_floats(start, stop, step):
    while stop > start:
        yield start
        start += step

# %%
# Set the parameters by cross-validation
tuned_parameters = [
    {"kernel": ["linear"], "C": list(range_with_floats(.5,10,.5))},
]

scores = ["accuracy"]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(svm.SVC(max_iter = 1000000), tuned_parameters, scoring="accuracy")
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_["mean_test_score"]
    stds = clf.cv_results_["std_test_score"]
    for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for accuracy
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Best parameters set found on development set:
#
# {'C': 1.5, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.828 (+/-0.044) for {'C': 0.5, 'kernel': 'linear'}
# 0.832 (+/-0.051) for {'C': 1.0, 'kernel': 'linear'}
# 0.835 (+/-0.058) for {'C': 1.5, 'kernel': 'linear'}
# 0.834 (+/-0.054) for {'C': 2.0, 'kernel': 'linear'}
# 0.835 (+/-0.048) for {'C': 2.5, 'kernel': 'linear'}
# 0.832 (+/-0.051) for {'C': 3.0, 'kernel': 'linear'}
# 0.832 (+/-0.044) for {'C': 3.5, 'kernel': 'linear'}
# 0.834 (+/-0.047) for {'C': 4.0, 'kernel': 'linear'}
# 0.824 (+/-0.055) for {'C': 4.5, 'kernel': 'linear'}
# 0.832 (+/-0.057) for {'C': 5.0, 'kernel': 'linear'}
# 0.834 (+/-0.053) for {'C': 5.5, 'kernel': 'linear'}
# 0.828 (+/-0.055) for {'C': 6.0, 'kernel': 'linear'}
# 0.832 (+/-0.052) for {'C': 6.5, 'kernel': 'linear'}
# 0.830 (+/-0.053) for {'C': 7.0, 'kernel': 'linear'}
# 0.765 (+/-0.242) for {'C': 7.5, 'kernel': 'linear'}
# 0.826 (+/-0.049) for {'C': 8.0, 'kernel': 'linear'}
# 0.828 (+/-0.048) for {'C': 8.5, 'kernel': 'linear'}
# 0.825 (+/-0.052) for {'C': 9.0, 'kernel': 'linear'}
# 0.770 (+/-0.237) for {'C': 9.5, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#           CH       0.87      0.87      0.87       165
#           MM       0.79      0.79      0.79       105
#
#     accuracy                           0.84       270
#    macro avg       0.83      0.83      0.83       270
# weighted avg       0.84      0.84      0.84       270

# %% [markdown]
# Using GridSearchCV as suggested in the homework slack, the best C value to use in this situation is C = 1.5. We do not necessarily check the one-stderr rule as we trust that GridSearchCV handles this in its calculations.

# %%
finalLinear = svm.SVC(kernel= 'linear', C= 1.5)
finalLinear.fit(X_train, y_train)
# Out:
# SVC(C=1.5, kernel='linear')

# %%
testPreds = finalLinear.predict(X_test)
trainPreds = finalLinear.predict(X_train)

# %% [markdown]
# ##### e)

# %%
print("Train error is:",1-accuracy_score(y_train, trainPreds), "   Test error is:",1-accuracy_score(y_test,testPreds))
# Out:
# Train error is: 0.15874999999999995    Test error is: 0.16296296296296298

# %% [markdown]
# ##### Part F
# For a svc with a radial bassis function kernel, the gamma value is inversely proportional to the standard deviation. As gamma decreases, we can say that the standard deviation of our model is increasing. In this kernel, as gamma decreases, there is less of an emphasis on distance between points, making points that are farther away from each other to be considered as more similar. With a higher gamma, the model sees every point as more dissimilar, whicch drives the model to overfitting. When we have a smaller gamma, the model tends to generalize better and group more points similarly which results in us seeing a more simple model in that scenario.

# %% [markdown]
# #### G

# %%
kernelRBF = svm.SVC(kernel= 'rbf')
kernelRBF.fit(X_train, y_train)

testPreds = kernelRBF.predict(X_test)
trainPreds = kernelRBF.predict(X_train)

# %%
len(kernelRBF.support_vectors_)
# Out:
# 630

# %% [markdown]
# The base RBF kernel has 630 support vectors and a test error of 0.37. There are the most support vectors in this model (although not by much) which signifies that it has the most complex hyperplane construction. The high test error goes to show that this type of kernel is sensitive to hyperparameter tuning.

# %%
print("Train error is:",1-accuracy_score(y_train, trainPreds), "   Test error is:",1-accuracy_score(y_test,testPreds))
# Out:
# Train error is: 0.39625    Test error is: 0.37037037037037035

# %%
# Set the parameters by cross-validation
tuned_parameters = [
    {"kernel": ["rbf"], "gamma": list(range_with_floats(.01,5,.5)), "C": list(range_with_floats(1,5,.5))},
]

scores = ["accuracy"]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(svm.SVC(max_iter = 1000000), tuned_parameters, scoring="accuracy")
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_["mean_test_score"]
    stds = clf.cv_results_["std_test_score"]
    for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'C': 4.5, 'gamma': 0.01, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.666 (+/-0.037) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.736 (+/-0.062) for {'C': 1, 'gamma': 0.51, 'kernel': 'rbf'}
# 0.704 (+/-0.055) for {'C': 1, 'gamma': 1.01, 'kernel': 'rbf'}
# 0.695 (+/-0.058) for {'C': 1, 'gamma': 1.51, 'kernel': 'rbf'}
# 0.696 (+/-0.068) for {'C': 1, 'gamma': 2.01, 'kernel': 'rbf'}
# 0.694 (+/-0.080) for {'C': 1, 'gamma': 2.51, 'kernel': 'rbf'}
# 0.700 (+/-0.084) for {'C': 1, 'gamma': 3.01, 'kernel': 'rbf'}
# 0.701 (+/-0.087) for {'C': 1, 'gamma': 3.51, 'kernel': 'rbf'}
# 0.699 (+/-0.082) for {'C': 1, 'gamma': 4.01, 'kernel': 'rbf'}
# 0.699 (+/-0.087) for {'C': 1, 'gamma': 4.51, 'kernel': 'rbf'}
# 0.696 (+/-0.059) for {'C': 1.5, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.733 (+/-0.060) for {'C': 1.5, 'gamma': 0.51, 'kernel': 'rbf'}
# 0.700 (+/-0.065) for {'C': 1.5, 'gamma': 1.01, 'kernel': 'rbf'}
# 0.694 (+/-0.075) for {'C': 1.5, 'gamma': 1.51, 'kernel': 'rbf'}
# 0.691 (+/-0.091) for {'C': 1.5, 'gamma': 2.01, 'kernel': 'rbf'}
# 0.693 (+/-0.094) for {'C': 1.5, 'gamma': 2.51, 'kernel': 'rbf'}
# 0.696 (+/-0.099) for {'C': 1.5, 'gamma': 3.01, 'kernel': 'rbf'}
# 0.703 (+/-0.099) for {'C': 1.5, 'gamma': 3.51, 'kernel': 'rbf'}
# 0.700 (+/-0.092) for {'C': 1.5, 'gamma': 4.01, 'kernel': 'rbf'}
# 0.698 (+/-0.092) for {'C': 1.5, 'gamma': 4.51, 'kernel': 'rbf'}
# 0.714 (+/-0.069) for {'C': 2.0, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.726 (+/-0.087) for {'C': 2.0, 'gamma': 0.51, 'kernel': 'rbf'}
# 0.708 (+/-0.091) for {'C': 2.0, 'gamma': 1.01, 'kernel': 'rbf'}
# 0.698 (+/-0.065) for {'C': 2.0, 'gamma': 1.51, 'kernel': 'rbf'}
# 0.695 (+/-0.094) for {'C': 2.0, 'gamma': 2.01, 'kernel': 'rbf'}
# 0.698 (+/-0.101) for {'C': 2.0, 'gamma': 2.51, 'kernel': 'rbf'}
# 0.696 (+/-0.100) for {'C': 2.0, 'gamma': 3.01, 'kernel': 'rbf'}
# 0.696 (+/-0.094) for {'C': 2.0, 'gamma': 3.51, 'kernel': 'rbf'}
# 0.693 (+/-0.094) for {'C': 2.0, 'gamma': 4.01, 'kernel': 'rbf'}
# 0.691 (+/-0.089) for {'C': 2.0, 'gamma': 4.51, 'kernel': 'rbf'}
# 0.729 (+/-0.064) for {'C': 2.5, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.730 (+/-0.078) for {'C': 2.5, 'gamma': 0.51, 'kernel': 'rbf'}
# 0.707 (+/-0.080) for {'C': 2.5, 'gamma': 1.01, 'kernel': 'rbf'}
# 0.700 (+/-0.072) for {'C': 2.5, 'gamma': 1.51, 'kernel': 'rbf'}
# 0.700 (+/-0.100) for {'C': 2.5, 'gamma': 2.01, 'kernel': 'rbf'}
# 0.696 (+/-0.100) for {'C': 2.5, 'gamma': 2.51, 'kernel': 'rbf'}
# 0.694 (+/-0.100) for {'C': 2.5, 'gamma': 3.01, 'kernel': 'rbf'}
# 0.693 (+/-0.097) for {'C': 2.5, 'gamma': 3.51, 'kernel': 'rbf'}
# 0.691 (+/-0.098) for {'C': 2.5, 'gamma': 4.01, 'kernel': 'rbf'}
# 0.690 (+/-0.094) for {'C': 2.5, 'gamma': 4.51, 'kernel': 'rbf'}
# 0.741 (+/-0.054) for {'C': 3.0, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.738 (+/-0.077) for {'C': 3.0, 'gamma': 0.51, 'kernel': 'rbf'}
# 0.719 (+/-0.088) for {'C': 3.0, 'gamma': 1.01, 'kernel': 'rbf'}
# 0.706 (+/-0.075) for {'C': 3.0, 'gamma': 1.51, 'kernel': 'rbf'}
# 0.699 (+/-0.098) for {'C': 3.0, 'gamma': 2.01, 'kernel': 'rbf'}
# 0.694 (+/-0.100) for {'C': 3.0, 'gamma': 2.51, 'kernel': 'rbf'}
# 0.689 (+/-0.102) for {'C': 3.0, 'gamma': 3.01, 'kernel': 'rbf'}
# 0.691 (+/-0.101) for {'C': 3.0, 'gamma': 3.51, 'kernel': 'rbf'}
# 0.689 (+/-0.103) for {'C': 3.0, 'gamma': 4.01, 'kernel': 'rbf'}
# 0.690 (+/-0.103) for {'C': 3.0, 'gamma': 4.51, 'kernel': 'rbf'}
# 0.761 (+/-0.064) for {'C': 3.5, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.739 (+/-0.076) for {'C': 3.5, 'gamma': 0.51, 'kernel': 'rbf'}
# 0.717 (+/-0.074) for {'C': 3.5, 'gamma': 1.01, 'kernel': 'rbf'}
# 0.708 (+/-0.078) for {'C': 3.5, 'gamma': 1.51, 'kernel': 'rbf'}
# 0.696 (+/-0.101) for {'C': 3.5, 'gamma': 2.01, 'kernel': 'rbf'}
# 0.693 (+/-0.097) for {'C': 3.5, 'gamma': 2.51, 'kernel': 'rbf'}
# 0.686 (+/-0.110) for {'C': 3.5, 'gamma': 3.01, 'kernel': 'rbf'}
# 0.691 (+/-0.105) for {'C': 3.5, 'gamma': 3.51, 'kernel': 'rbf'}
# 0.693 (+/-0.106) for {'C': 3.5, 'gamma': 4.01, 'kernel': 'rbf'}
# 0.690 (+/-0.100) for {'C': 3.5, 'gamma': 4.51, 'kernel': 'rbf'}
# 0.776 (+/-0.073) for {'C': 4.0, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.741 (+/-0.075) for {'C': 4.0, 'gamma': 0.51, 'kernel': 'rbf'}
# 0.716 (+/-0.080) for {'C': 4.0, 'gamma': 1.01, 'kernel': 'rbf'}
# 0.706 (+/-0.072) for {'C': 4.0, 'gamma': 1.51, 'kernel': 'rbf'}
# 0.698 (+/-0.100) for {'C': 4.0, 'gamma': 2.01, 'kernel': 'rbf'}
# 0.690 (+/-0.103) for {'C': 4.0, 'gamma': 2.51, 'kernel': 'rbf'}
# 0.688 (+/-0.111) for {'C': 4.0, 'gamma': 3.01, 'kernel': 'rbf'}
# 0.691 (+/-0.105) for {'C': 4.0, 'gamma': 3.51, 'kernel': 'rbf'}
# 0.691 (+/-0.104) for {'C': 4.0, 'gamma': 4.01, 'kernel': 'rbf'}
# 0.690 (+/-0.100) for {'C': 4.0, 'gamma': 4.51, 'kernel': 'rbf'}
# 0.790 (+/-0.056) for {'C': 4.5, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.742 (+/-0.074) for {'C': 4.5, 'gamma': 0.51, 'kernel': 'rbf'}
# 0.718 (+/-0.084) for {'C': 4.5, 'gamma': 1.01, 'kernel': 'rbf'}
# 0.706 (+/-0.069) for {'C': 4.5, 'gamma': 1.51, 'kernel': 'rbf'}
# 0.696 (+/-0.097) for {'C': 4.5, 'gamma': 2.01, 'kernel': 'rbf'}
# 0.689 (+/-0.107) for {'C': 4.5, 'gamma': 2.51, 'kernel': 'rbf'}
# 0.688 (+/-0.111) for {'C': 4.5, 'gamma': 3.01, 'kernel': 'rbf'}
# 0.691 (+/-0.104) for {'C': 4.5, 'gamma': 3.51, 'kernel': 'rbf'}
# 0.689 (+/-0.111) for {'C': 4.5, 'gamma': 4.01, 'kernel': 'rbf'}
# 0.689 (+/-0.098) for {'C': 4.5, 'gamma': 4.51, 'kernel': 'rbf'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#           CH       0.81      0.86      0.84       165
#           MM       0.76      0.69      0.72       105
#
#     accuracy                           0.79       270
#    macro avg       0.78      0.77      0.78       270
# weighted avg       0.79      0.79      0.79       270

# %% [markdown]
# The selected parameters for this model are C=4.5 and gamma = 0.01. We use GridSearchCV which executes cross validation to find these parameters, as specified in the slack channel.

# %%
finalRBF = svm.SVC(kernel= 'rbf', gamma = 0.01,C=4.5)
finalRBF.fit(X_train, y_train)

testPreds = finalRBF.predict(X_test)
trainPreds = finalRBF.predict(X_train)

# %%
print("Train error is:",1-accuracy_score(y_train, trainPreds), "   Test error is:",1-accuracy_score(y_test,testPreds))
# Out:
# Train error is: 0.1825    Test error is: 0.20740740740740737

# %% [markdown]
# ##### h)

# %%
polyKernel = svm.SVC(kernel= 'poly', degree = 2)
polyKernel.fit(X_train, y_train)

testPreds = polyKernel.predict(X_test)
trainPreds = polyKernel.predict(X_train)

# %%
print(len(polyKernel.support_vectors_))
# Out:
# 626

# %% [markdown]
# The base polynomial kernel SVC with a degree of 2 has 626 support vectors, and a test error of 0.37. Compared to the linear kernel, this base model has just about the same number of support vectors but a much higher test error rate. This goes to show that non-linear kernels are much more sensitive to hyperparameter tuning.

# %%
print("Train error is:",1-accuracy_score(y_train, trainPreds), "   Test error is:",1-accuracy_score(y_test,testPreds))
# Out:
# Train error is: 0.39625    Test error is: 0.37037037037037035

# %%
# Set the parameters by cross-validation
tuned_parameters = [
    {"kernel": ["poly"],"degree": [2], "gamma": list(range_with_floats(.001,1,.05)), "C": list(range_with_floats(1,5,.5))},
]

scores = ["accuracy"]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(svm.SVC(max_iter = 1000000), tuned_parameters, scoring="accuracy")
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_["mean_test_score"]
    stds = clf.cv_results_["std_test_score"]
    for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for accuracy
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# ...
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Best parameters set found on development set:
#
# {'C': 4.0, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
#
# Grid scores on development set:
#
# 0.815 (+/-0.047) for {'C': 1, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.795 (+/-0.112) for {'C': 1, 'degree': 2, 'gamma': 0.051000000000000004, 'kernel': 'poly'}
# 0.757 (+/-0.118) for {'C': 1, 'degree': 2, 'gamma': 0.101, 'kernel': 'poly'}
# 0.761 (+/-0.124) for {'C': 1, 'degree': 2, 'gamma': 0.15100000000000002, 'kernel': 'poly'}
# 0.751 (+/-0.163) for {'C': 1, 'degree': 2, 'gamma': 0.201, 'kernel': 'poly'}
# 0.745 (+/-0.291) for {'C': 1, 'degree': 2, 'gamma': 0.251, 'kernel': 'poly'}
# 0.790 (+/-0.105) for {'C': 1, 'degree': 2, 'gamma': 0.301, 'kernel': 'poly'}
# 0.756 (+/-0.108) for {'C': 1, 'degree': 2, 'gamma': 0.351, 'kernel': 'poly'}
# 0.799 (+/-0.056) for {'C': 1, 'degree': 2, 'gamma': 0.40099999999999997, 'kernel': 'poly'}
# 0.749 (+/-0.073) for {'C': 1, 'degree': 2, 'gamma': 0.45099999999999996, 'kernel': 'poly'}
# 0.800 (+/-0.058) for {'C': 1, 'degree': 2, 'gamma': 0.501, 'kernel': 'poly'}
# 0.796 (+/-0.077) for {'C': 1, 'degree': 2, 'gamma': 0.551, 'kernel': 'poly'}
# 0.796 (+/-0.042) for {'C': 1, 'degree': 2, 'gamma': 0.6010000000000001, 'kernel': 'poly'}
# 0.695 (+/-0.319) for {'C': 1, 'degree': 2, 'gamma': 0.6510000000000001, 'kernel': 'poly'}
# 0.790 (+/-0.107) for {'C': 1, 'degree': 2, 'gamma': 0.7010000000000002, 'kernel': 'poly'}
# 0.740 (+/-0.232) for {'C': 1, 'degree': 2, 'gamma': 0.7510000000000002, 'kernel': 'poly'}
# 0.797 (+/-0.050) for {'C': 1, 'degree': 2, 'gamma': 0.8010000000000003, 'kernel': 'poly'}
# 0.708 (+/-0.272) for {'C': 1, 'degree': 2, 'gamma': 0.8510000000000003, 'kernel': 'poly'}
# 0.799 (+/-0.087) for {'C': 1, 'degree': 2, 'gamma': 0.9010000000000004, 'kernel': 'poly'}
# 0.780 (+/-0.073) for {'C': 1, 'degree': 2, 'gamma': 0.9510000000000004, 'kernel': 'poly'}
# 0.821 (+/-0.047) for {'C': 1.5, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.764 (+/-0.163) for {'C': 1.5, 'degree': 2, 'gamma': 0.051000000000000004, 'kernel': 'poly'}
# 0.802 (+/-0.039) for {'C': 1.5, 'degree': 2, 'gamma': 0.101, 'kernel': 'poly'}
# 0.801 (+/-0.046) for {'C': 1.5, 'degree': 2, 'gamma': 0.15100000000000002, 'kernel': 'poly'}
# 0.791 (+/-0.113) for {'C': 1.5, 'degree': 2, 'gamma': 0.201, 'kernel': 'poly'}
# 0.745 (+/-0.259) for {'C': 1.5, 'degree': 2, 'gamma': 0.251, 'kernel': 'poly'}
# 0.792 (+/-0.089) for {'C': 1.5, 'degree': 2, 'gamma': 0.301, 'kernel': 'poly'}
# 0.802 (+/-0.079) for {'C': 1.5, 'degree': 2, 'gamma': 0.351, 'kernel': 'poly'}
# 0.756 (+/-0.191) for {'C': 1.5, 'degree': 2, 'gamma': 0.40099999999999997, 'kernel': 'poly'}
# 0.806 (+/-0.029) for {'C': 1.5, 'degree': 2, 'gamma': 0.45099999999999996, 'kernel': 'poly'}
# 0.786 (+/-0.107) for {'C': 1.5, 'degree': 2, 'gamma': 0.501, 'kernel': 'poly'}
# 0.781 (+/-0.109) for {'C': 1.5, 'degree': 2, 'gamma': 0.551, 'kernel': 'poly'}
# 0.771 (+/-0.123) for {'C': 1.5, 'degree': 2, 'gamma': 0.6010000000000001, 'kernel': 'poly'}
# 0.600 (+/-0.253) for {'C': 1.5, 'degree': 2, 'gamma': 0.6510000000000001, 'kernel': 'poly'}
# 0.794 (+/-0.058) for {'C': 1.5, 'degree': 2, 'gamma': 0.7010000000000002, 'kernel': 'poly'}
# 0.730 (+/-0.268) for {'C': 1.5, 'degree': 2, 'gamma': 0.7510000000000002, 'kernel': 'poly'}
# 0.776 (+/-0.105) for {'C': 1.5, 'degree': 2, 'gamma': 0.8010000000000003, 'kernel': 'poly'}
# 0.711 (+/-0.277) for {'C': 1.5, 'degree': 2, 'gamma': 0.8510000000000003, 'kernel': 'poly'}
# 0.762 (+/-0.106) for {'C': 1.5, 'degree': 2, 'gamma': 0.9010000000000004, 'kernel': 'poly'}
# 0.787 (+/-0.117) for {'C': 1.5, 'degree': 2, 'gamma': 0.9510000000000004, 'kernel': 'poly'}
# 0.823 (+/-0.047) for {'C': 2.0, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.726 (+/-0.297) for {'C': 2.0, 'degree': 2, 'gamma': 0.051000000000000004, 'kernel': 'poly'}
# 0.798 (+/-0.053) for {'C': 2.0, 'degree': 2, 'gamma': 0.101, 'kernel': 'poly'}
# 0.774 (+/-0.062) for {'C': 2.0, 'degree': 2, 'gamma': 0.15100000000000002, 'kernel': 'poly'}
# 0.794 (+/-0.096) for {'C': 2.0, 'degree': 2, 'gamma': 0.201, 'kernel': 'poly'}
# 0.814 (+/-0.056) for {'C': 2.0, 'degree': 2, 'gamma': 0.251, 'kernel': 'poly'}
# 0.799 (+/-0.072) for {'C': 2.0, 'degree': 2, 'gamma': 0.301, 'kernel': 'poly'}
# 0.769 (+/-0.077) for {'C': 2.0, 'degree': 2, 'gamma': 0.351, 'kernel': 'poly'}
# 0.747 (+/-0.260) for {'C': 2.0, 'degree': 2, 'gamma': 0.40099999999999997, 'kernel': 'poly'}
# 0.819 (+/-0.078) for {'C': 2.0, 'degree': 2, 'gamma': 0.45099999999999996, 'kernel': 'poly'}
# 0.764 (+/-0.133) for {'C': 2.0, 'degree': 2, 'gamma': 0.501, 'kernel': 'poly'}
# 0.793 (+/-0.057) for {'C': 2.0, 'degree': 2, 'gamma': 0.551, 'kernel': 'poly'}
# 0.815 (+/-0.076) for {'C': 2.0, 'degree': 2, 'gamma': 0.6010000000000001, 'kernel': 'poly'}
# 0.645 (+/-0.246) for {'C': 2.0, 'degree': 2, 'gamma': 0.6510000000000001, 'kernel': 'poly'}
# 0.781 (+/-0.136) for {'C': 2.0, 'degree': 2, 'gamma': 0.7010000000000002, 'kernel': 'poly'}
# 0.785 (+/-0.059) for {'C': 2.0, 'degree': 2, 'gamma': 0.7510000000000002, 'kernel': 'poly'}
# 0.819 (+/-0.068) for {'C': 2.0, 'degree': 2, 'gamma': 0.8010000000000003, 'kernel': 'poly'}
# 0.713 (+/-0.275) for {'C': 2.0, 'degree': 2, 'gamma': 0.8510000000000003, 'kernel': 'poly'}
# 0.738 (+/-0.155) for {'C': 2.0, 'degree': 2, 'gamma': 0.9010000000000004, 'kernel': 'poly'}
# 0.774 (+/-0.091) for {'C': 2.0, 'degree': 2, 'gamma': 0.9510000000000004, 'kernel': 'poly'}
# 0.826 (+/-0.046) for {'C': 2.5, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.806 (+/-0.057) for {'C': 2.5, 'degree': 2, 'gamma': 0.051000000000000004, 'kernel': 'poly'}
# 0.760 (+/-0.269) for {'C': 2.5, 'degree': 2, 'gamma': 0.101, 'kernel': 'poly'}
# 0.749 (+/-0.203) for {'C': 2.5, 'degree': 2, 'gamma': 0.15100000000000002, 'kernel': 'poly'}
# 0.776 (+/-0.106) for {'C': 2.5, 'degree': 2, 'gamma': 0.201, 'kernel': 'poly'}
# 0.707 (+/-0.233) for {'C': 2.5, 'degree': 2, 'gamma': 0.251, 'kernel': 'poly'}
# 0.757 (+/-0.139) for {'C': 2.5, 'degree': 2, 'gamma': 0.301, 'kernel': 'poly'}
# 0.794 (+/-0.086) for {'C': 2.5, 'degree': 2, 'gamma': 0.351, 'kernel': 'poly'}
# 0.770 (+/-0.058) for {'C': 2.5, 'degree': 2, 'gamma': 0.40099999999999997, 'kernel': 'poly'}
# 0.796 (+/-0.058) for {'C': 2.5, 'degree': 2, 'gamma': 0.45099999999999996, 'kernel': 'poly'}
# 0.772 (+/-0.068) for {'C': 2.5, 'degree': 2, 'gamma': 0.501, 'kernel': 'poly'}
# 0.770 (+/-0.071) for {'C': 2.5, 'degree': 2, 'gamma': 0.551, 'kernel': 'poly'}
# 0.730 (+/-0.102) for {'C': 2.5, 'degree': 2, 'gamma': 0.6010000000000001, 'kernel': 'poly'}
# 0.631 (+/-0.288) for {'C': 2.5, 'degree': 2, 'gamma': 0.6510000000000001, 'kernel': 'poly'}
# 0.769 (+/-0.065) for {'C': 2.5, 'degree': 2, 'gamma': 0.7010000000000002, 'kernel': 'poly'}
# 0.775 (+/-0.059) for {'C': 2.5, 'degree': 2, 'gamma': 0.7510000000000002, 'kernel': 'poly'}
# 0.735 (+/-0.298) for {'C': 2.5, 'degree': 2, 'gamma': 0.8010000000000003, 'kernel': 'poly'}
# 0.716 (+/-0.279) for {'C': 2.5, 'degree': 2, 'gamma': 0.8510000000000003, 'kernel': 'poly'}
# 0.741 (+/-0.119) for {'C': 2.5, 'degree': 2, 'gamma': 0.9010000000000004, 'kernel': 'poly'}
# 0.759 (+/-0.255) for {'C': 2.5, 'degree': 2, 'gamma': 0.9510000000000004, 'kernel': 'poly'}
# 0.828 (+/-0.039) for {'C': 3.0, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.784 (+/-0.067) for {'C': 3.0, 'degree': 2, 'gamma': 0.051000000000000004, 'kernel': 'poly'}
# 0.804 (+/-0.093) for {'C': 3.0, 'degree': 2, 'gamma': 0.101, 'kernel': 'poly'}
# 0.769 (+/-0.082) for {'C': 3.0, 'degree': 2, 'gamma': 0.15100000000000002, 'kernel': 'poly'}
# 0.774 (+/-0.114) for {'C': 3.0, 'degree': 2, 'gamma': 0.201, 'kernel': 'poly'}
# 0.797 (+/-0.116) for {'C': 3.0, 'degree': 2, 'gamma': 0.251, 'kernel': 'poly'}
# 0.711 (+/-0.200) for {'C': 3.0, 'degree': 2, 'gamma': 0.301, 'kernel': 'poly'}
# 0.795 (+/-0.061) for {'C': 3.0, 'degree': 2, 'gamma': 0.351, 'kernel': 'poly'}
# 0.755 (+/-0.267) for {'C': 3.0, 'degree': 2, 'gamma': 0.40099999999999997, 'kernel': 'poly'}
# 0.790 (+/-0.087) for {'C': 3.0, 'degree': 2, 'gamma': 0.45099999999999996, 'kernel': 'poly'}
# 0.804 (+/-0.052) for {'C': 3.0, 'degree': 2, 'gamma': 0.501, 'kernel': 'poly'}
# 0.751 (+/-0.132) for {'C': 3.0, 'degree': 2, 'gamma': 0.551, 'kernel': 'poly'}
# 0.691 (+/-0.118) for {'C': 3.0, 'degree': 2, 'gamma': 0.6010000000000001, 'kernel': 'poly'}
# 0.759 (+/-0.196) for {'C': 3.0, 'degree': 2, 'gamma': 0.6510000000000001, 'kernel': 'poly'}
# 0.797 (+/-0.070) for {'C': 3.0, 'degree': 2, 'gamma': 0.7010000000000002, 'kernel': 'poly'}
# 0.716 (+/-0.254) for {'C': 3.0, 'degree': 2, 'gamma': 0.7510000000000002, 'kernel': 'poly'}
# 0.779 (+/-0.095) for {'C': 3.0, 'degree': 2, 'gamma': 0.8010000000000003, 'kernel': 'poly'}
# 0.734 (+/-0.297) for {'C': 3.0, 'degree': 2, 'gamma': 0.8510000000000003, 'kernel': 'poly'}
# 0.800 (+/-0.047) for {'C': 3.0, 'degree': 2, 'gamma': 0.9010000000000004, 'kernel': 'poly'}
# 0.814 (+/-0.054) for {'C': 3.0, 'degree': 2, 'gamma': 0.9510000000000004, 'kernel': 'poly'}
# 0.832 (+/-0.048) for {'C': 3.5, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.799 (+/-0.042) for {'C': 3.5, 'degree': 2, 'gamma': 0.051000000000000004, 'kernel': 'poly'}
# 0.755 (+/-0.169) for {'C': 3.5, 'degree': 2, 'gamma': 0.101, 'kernel': 'poly'}
# 0.776 (+/-0.134) for {'C': 3.5, 'degree': 2, 'gamma': 0.15100000000000002, 'kernel': 'poly'}
# 0.814 (+/-0.070) for {'C': 3.5, 'degree': 2, 'gamma': 0.201, 'kernel': 'poly'}
# 0.645 (+/-0.330) for {'C': 3.5, 'degree': 2, 'gamma': 0.251, 'kernel': 'poly'}
# 0.771 (+/-0.167) for {'C': 3.5, 'degree': 2, 'gamma': 0.301, 'kernel': 'poly'}
# 0.739 (+/-0.094) for {'C': 3.5, 'degree': 2, 'gamma': 0.351, 'kernel': 'poly'}
# 0.775 (+/-0.066) for {'C': 3.5, 'degree': 2, 'gamma': 0.40099999999999997, 'kernel': 'poly'}
# 0.830 (+/-0.074) for {'C': 3.5, 'degree': 2, 'gamma': 0.45099999999999996, 'kernel': 'poly'}
# 0.784 (+/-0.087) for {'C': 3.5, 'degree': 2, 'gamma': 0.501, 'kernel': 'poly'}
# 0.808 (+/-0.117) for {'C': 3.5, 'degree': 2, 'gamma': 0.551, 'kernel': 'poly'}
# 0.800 (+/-0.081) for {'C': 3.5, 'degree': 2, 'gamma': 0.6010000000000001, 'kernel': 'poly'}
# 0.688 (+/-0.208) for {'C': 3.5, 'degree': 2, 'gamma': 0.6510000000000001, 'kernel': 'poly'}
# 0.758 (+/-0.127) for {'C': 3.5, 'degree': 2, 'gamma': 0.7010000000000002, 'kernel': 'poly'}
# 0.758 (+/-0.134) for {'C': 3.5, 'degree': 2, 'gamma': 0.7510000000000002, 'kernel': 'poly'}
# 0.789 (+/-0.037) for {'C': 3.5, 'degree': 2, 'gamma': 0.8010000000000003, 'kernel': 'poly'}
# 0.726 (+/-0.293) for {'C': 3.5, 'degree': 2, 'gamma': 0.8510000000000003, 'kernel': 'poly'}
# 0.802 (+/-0.042) for {'C': 3.5, 'degree': 2, 'gamma': 0.9010000000000004, 'kernel': 'poly'}
# 0.733 (+/-0.310) for {'C': 3.5, 'degree': 2, 'gamma': 0.9510000000000004, 'kernel': 'poly'}
# 0.833 (+/-0.045) for {'C': 4.0, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.720 (+/-0.199) for {'C': 4.0, 'degree': 2, 'gamma': 0.051000000000000004, 'kernel': 'poly'}
# 0.805 (+/-0.086) for {'C': 4.0, 'degree': 2, 'gamma': 0.101, 'kernel': 'poly'}
# 0.731 (+/-0.105) for {'C': 4.0, 'degree': 2, 'gamma': 0.15100000000000002, 'kernel': 'poly'}
# 0.762 (+/-0.100) for {'C': 4.0, 'degree': 2, 'gamma': 0.201, 'kernel': 'poly'}
# 0.750 (+/-0.213) for {'C': 4.0, 'degree': 2, 'gamma': 0.251, 'kernel': 'poly'}
# 0.782 (+/-0.084) for {'C': 4.0, 'degree': 2, 'gamma': 0.301, 'kernel': 'poly'}
# 0.812 (+/-0.075) for {'C': 4.0, 'degree': 2, 'gamma': 0.351, 'kernel': 'poly'}
# 0.772 (+/-0.036) for {'C': 4.0, 'degree': 2, 'gamma': 0.40099999999999997, 'kernel': 'poly'}
# 0.801 (+/-0.038) for {'C': 4.0, 'degree': 2, 'gamma': 0.45099999999999996, 'kernel': 'poly'}
# 0.719 (+/-0.217) for {'C': 4.0, 'degree': 2, 'gamma': 0.501, 'kernel': 'poly'}
# 0.776 (+/-0.124) for {'C': 4.0, 'degree': 2, 'gamma': 0.551, 'kernel': 'poly'}
# 0.804 (+/-0.085) for {'C': 4.0, 'degree': 2, 'gamma': 0.6010000000000001, 'kernel': 'poly'}
# 0.749 (+/-0.235) for {'C': 4.0, 'degree': 2, 'gamma': 0.6510000000000001, 'kernel': 'poly'}
# 0.775 (+/-0.052) for {'C': 4.0, 'degree': 2, 'gamma': 0.7010000000000002, 'kernel': 'poly'}
# 0.704 (+/-0.223) for {'C': 4.0, 'degree': 2, 'gamma': 0.7510000000000002, 'kernel': 'poly'}
# 0.823 (+/-0.028) for {'C': 4.0, 'degree': 2, 'gamma': 0.8010000000000003, 'kernel': 'poly'}
# 0.666 (+/-0.238) for {'C': 4.0, 'degree': 2, 'gamma': 0.8510000000000003, 'kernel': 'poly'}
# 0.800 (+/-0.044) for {'C': 4.0, 'degree': 2, 'gamma': 0.9010000000000004, 'kernel': 'poly'}
# 0.780 (+/-0.100) for {'C': 4.0, 'degree': 2, 'gamma': 0.9510000000000004, 'kernel': 'poly'}
# 0.831 (+/-0.044) for {'C': 4.5, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.808 (+/-0.018) for {'C': 4.5, 'degree': 2, 'gamma': 0.051000000000000004, 'kernel': 'poly'}
# 0.716 (+/-0.302) for {'C': 4.5, 'degree': 2, 'gamma': 0.101, 'kernel': 'poly'}
# 0.733 (+/-0.115) for {'C': 4.5, 'degree': 2, 'gamma': 0.15100000000000002, 'kernel': 'poly'}
# 0.786 (+/-0.101) for {'C': 4.5, 'degree': 2, 'gamma': 0.201, 'kernel': 'poly'}
# 0.769 (+/-0.153) for {'C': 4.5, 'degree': 2, 'gamma': 0.251, 'kernel': 'poly'}
# 0.795 (+/-0.036) for {'C': 4.5, 'degree': 2, 'gamma': 0.301, 'kernel': 'poly'}
# 0.791 (+/-0.048) for {'C': 4.5, 'degree': 2, 'gamma': 0.351, 'kernel': 'poly'}
# 0.750 (+/-0.263) for {'C': 4.5, 'degree': 2, 'gamma': 0.40099999999999997, 'kernel': 'poly'}
# 0.770 (+/-0.067) for {'C': 4.5, 'degree': 2, 'gamma': 0.45099999999999996, 'kernel': 'poly'}
# 0.799 (+/-0.065) for {'C': 4.5, 'degree': 2, 'gamma': 0.501, 'kernel': 'poly'}
# 0.756 (+/-0.139) for {'C': 4.5, 'degree': 2, 'gamma': 0.551, 'kernel': 'poly'}
# 0.806 (+/-0.111) for {'C': 4.5, 'degree': 2, 'gamma': 0.6010000000000001, 'kernel': 'poly'}
# 0.739 (+/-0.205) for {'C': 4.5, 'degree': 2, 'gamma': 0.6510000000000001, 'kernel': 'poly'}
# 0.775 (+/-0.123) for {'C': 4.5, 'degree': 2, 'gamma': 0.7010000000000002, 'kernel': 'poly'}
# 0.794 (+/-0.072) for {'C': 4.5, 'degree': 2, 'gamma': 0.7510000000000002, 'kernel': 'poly'}
# 0.786 (+/-0.052) for {'C': 4.5, 'degree': 2, 'gamma': 0.8010000000000003, 'kernel': 'poly'}
# 0.738 (+/-0.296) for {'C': 4.5, 'degree': 2, 'gamma': 0.8510000000000003, 'kernel': 'poly'}
# 0.770 (+/-0.097) for {'C': 4.5, 'degree': 2, 'gamma': 0.9010000000000004, 'kernel': 'poly'}
# 0.772 (+/-0.106) for {'C': 4.5, 'degree': 2, 'gamma': 0.9510000000000004, 'kernel': 'poly'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#           CH       0.85      0.86      0.86       165
#           MM       0.78      0.76      0.77       105
#
#     accuracy                           0.82       270
#    macro avg       0.81      0.81      0.81       270
# weighted avg       0.82      0.82      0.82       270
# c:\users\adamw\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\_base.py:258: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# In this scenario, our selected parameters are C=4 and gamma = 0.001. As with the previous two models, we use GridSearchCV to execute the desired cross validation and find these parameters.

# %%
finalPoly = svm.SVC(kernel= 'poly',degree = 2, gamma= 0.001, C=4)
finalPoly.fit(X_train, y_train)

testPreds = finalPoly.predict(X_test)
trainPreds = finalPoly.predict(X_train)

# %%
print("Train error is:",1-accuracy_score(y_train, trainPreds), "   Test error is:",1-accuracy_score(y_test,testPreds))
# Out:
# Train error is: 0.16749999999999998    Test error is: 0.1777777777777778

# %% [markdown]
# ##### i)

# %% [markdown]
# Overall based on this data, the linear kernel approach seems to give the best results. While the polynomial degree 2 kernel performs slightly better on the the test data, the linear kernel is simpler and easier to understand. We also look towards the cross validation exercise while tweaking parameters and see tha the polynomial kernel model is incredibly volatile. This lends us to believe that as the data may evolve over time, our chosen value for gamma may not perform well. For the linear kernel model, there is much less volatility in error rate as we change the parameters, and what variability there is stays within a range that performs much better. Therefore, the linear kernel approach is the best model to choose for this data and going forward as we gather more data.
